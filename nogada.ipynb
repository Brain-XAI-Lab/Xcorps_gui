# %% [markdown]
# <a href="https://colab.research.google.com/github/hanbuck30/Xcorps_gui/blob/main/nogada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# %cd /content
df =pd.read_csv("result_01.csv")
df= df.drop(columns=['Unnamed: 0'])
df
# Out:
# /content
#                0             1             2             3             4  \
# 0   0.000000e+00  2.000000e+00  4.000000e+00  6.000000e+00  8.000000e+00
# 1   1.318731e+03  2.607778e+03  2.660372e+03  2.631314e+03  2.664529e+03
# 2  -1.439162e+03 -2.912298e+03 -2.872154e+03 -2.909147e+03 -2.868981e+03
# 3  -2.919942e+03 -5.891920e+03 -5.841740e+03 -5.857610e+03 -5.840287e+03
# 4  -1.600452e+03 -2.991468e+03 -2.998174e+03 -3.039368e+03 -2.955079e+03
# 5  -6.709301e+03 -1.341165e+04 -1.340776e+04 -1.340962e+04 -1.340103e+04
# 6   5.971693e+03  1.184110e+04  1.186165e+04  1.187126e+04  1.185302e+04
# 7   2.758026e+03  5.446852e+03  5.504274e+03  5.464845e+03  5.506352e+03
# 8  -1.915433e+03 -3.878899e+03 -3.843427e+03 -3.877871e+03 -3.847585e+03
# 9  -4.233644e+03 -8.736001e+03 -8.696259e+03 -8.733698e+03 -8.705334e+03
# 10 -2.391927e+03 -5.028204e+03 -5.068392e+03 -5.020962e+03 -5.072684e+03
# 11  1.303087e+04  2.260269e+04  2.264321e+04  2.260448e+04  2.263787e+04
# ...

# %%
row_31= df.iloc[31, :]
for i in range(1,23):
    globals()['index_{}'.format(i)] = row_31[row_31 == i].index.tolist()
row_31 = pd.DataFrame(row_31).T
df= pd.concat([df,row_31],axis=0)
df.iloc[32,int(index_1[0]):int(index_2[0])]=1

df.iloc[32,int(index_2[0]):int(index_3[0])]=2
df.iloc[32,int(index_3[0]):int(index_4[0])]=3
df.iloc[32,int(index_4[0]):int(index_3[1])]=4
df.iloc[32,int(index_3[1]):int(index_4[1])]=3
df.iloc[32,int(index_4[1]):int(index_3[2])]=4
df.iloc[32,int(index_3[2]):int(index_4[2])]=3
df.iloc[32,int(index_4[2]):int(index_3[3])]=4
df.iloc[32,int(index_3[3]):int(index_4[3])]=3
df.iloc[32,int(index_4[3]):int(index_2[1])]=4

df.iloc[32,int(index_2[1]):int(index_5[0])]=2
df.iloc[32,int(index_5[0]):int(index_6[0])]=5
df.iloc[32,int(index_6[0]):int(index_5[1])]=6
df.iloc[32,int(index_5[1]):int(index_6[1])]=5
df.iloc[32,int(index_6[1]):int(index_5[2])]=6
df.iloc[32,int(index_5[2]):int(index_6[2])]=5
df.iloc[32,int(index_6[2]):int(index_5[3])]=6
df.iloc[32,int(index_5[3]):int(index_6[3])]=5
df.iloc[32,int(index_6[3]):int(index_2[2])]=6

df.iloc[32,int(index_2[2]):int(index_7[0])]=2
df.iloc[32,int(index_7[0]):int(index_8[0])]=7
df.iloc[32,int(index_8[0]):int(index_7[1])]=8
df.iloc[32,int(index_7[1]):int(index_8[1])]=7
df.iloc[32,int(index_8[1]):int(index_7[2])]=8
df.iloc[32,int(index_7[2]):int(index_8[2])]=7
df.iloc[32,int(index_8[2]):int(index_7[3])]=8
df.iloc[32,int(index_7[3]):int(index_8[3])]=7
df.iloc[32,int(index_8[3]):int(index_2[3])]=8

df.iloc[32,int(index_2[3]):int(index_9[0])]=2
df.iloc[32,int(index_9[0]):int(index_10[0])]=9
df.iloc[32,int(index_10[0]):int(index_9[1])]=10
df.iloc[32,int(index_9[1]):int(index_10[1])]=9
df.iloc[32,int(index_10[1]):int(index_9[2])]=10
df.iloc[32,int(index_9[2]):int(index_10[2])]=9
df.iloc[32,int(index_10[2]):int(index_9[3])]=10
df.iloc[32,int(index_9[3]):int(index_10[3])]=9
df.iloc[32,int(index_10[3]):int(index_2[4])]=10

df.iloc[32,int(index_2[4]):int(index_11[0])]=2
df.iloc[32,int(index_11[0]):int(index_12[0])]=11
df.iloc[32,int(index_12[0]):int(index_11[1])]=12
df.iloc[32,int(index_11[1]):int(index_12[1])]=11
df.iloc[32,int(index_12[1]):int(index_11[2])]=12
df.iloc[32,int(index_11[2]):int(index_12[2])]=11
df.iloc[32,int(index_12[2]):int(index_11[3])]=12
df.iloc[32,int(index_11[3]):int(index_12[3])]=11
df.iloc[32,int(index_12[3]):int(index_2[5])]=12

df.iloc[32,int(index_2[5]):int(index_13[0])]=2
df.iloc[32,int(index_13[0]):int(index_14[0])]=13
df.iloc[32,int(index_14[0]):int(index_13[1])]=14
df.iloc[32,int(index_13[1]):int(index_14[1])]=13
df.iloc[32,int(index_14[1]):int(index_13[2])]=14
df.iloc[32,int(index_13[2]):int(index_14[2])]=13
df.iloc[32,int(index_14[2]):int(index_13[3])]=14
df.iloc[32,int(index_13[3]):int(index_14[3])]=13
df.iloc[32,int(index_14[3]):int(index_2[6])]=14

df.iloc[32,int(index_2[6]):int(index_15[0])]=2
df.iloc[32,int(index_15[0]):int(index_16[0])]=15
df.iloc[32,int(index_16[0]):int(index_15[1])]=16
df.iloc[32,int(index_15[1]):int(index_16[1])]=15
df.iloc[32,int(index_16[1]):int(index_15[2])]=16
df.iloc[32,int(index_15[2]):int(index_16[2])]=15
df.iloc[32,int(index_16[2]):int(index_15[3])]=16
df.iloc[32,int(index_15[3]):int(index_16[3])]=15
df.iloc[32,int(index_16[3]):int(index_2[7])]=16

df.iloc[32,int(index_2[7]):int(index_17[0])]=2
df.iloc[32,int(index_17[0]):int(index_18[0])]=17
df.iloc[32,int(index_18[0]):int(index_17[1])]=18
df.iloc[32,int(index_17[1]):int(index_18[1])]=17
df.iloc[32,int(index_18[1]):int(index_17[2])]=18
df.iloc[32,int(index_17[2]):int(index_18[2])]=17
df.iloc[32,int(index_18[2]):int(index_17[3])]=18
df.iloc[32,int(index_17[3]):int(index_18[3])]=17
df.iloc[32,int(index_18[3]):int(index_2[8])]=18

df.iloc[32,int(index_2[8]):int(index_19[0])]=2
df.iloc[32,int(index_19[0]):int(index_20[0])]=19
df.iloc[32,int(index_20[0]):int(index_19[1])]=20
df.iloc[32,int(index_19[1]):int(index_20[1])]=19
df.iloc[32,int(index_20[1]):int(index_19[2])]=20
df.iloc[32,int(index_19[2]):int(index_20[2])]=19
df.iloc[32,int(index_20[2]):int(index_19[3])]=20
df.iloc[32,int(index_19[3]):int(index_20[3])]=19
df.iloc[32,int(index_20[3]):int(index_2[9])]=20

df.iloc[32,int(index_2[8]):int(index_21[0])]=2
df.iloc[32,int(index_21[0]):int(index_22[0])]=21
df.iloc[32,int(index_22[0]):int(index_21[1])]=22
df.iloc[32,int(index_21[1]):int(index_22[1])]=21
df.iloc[32,int(index_22[1]):int(index_21[2])]=22
df.iloc[32,int(index_21[2]):int(index_22[2])]=21
df.iloc[32,int(index_22[2]):int(index_21[3])]=22
df.iloc[32,int(index_21[3]):int(index_22[3])]=21
df.iloc[32,int(index_22[3]):]=22

# %%
df=df.reset_index()
df=df.drop(columns=['index'])
df
# Out:
#                0             1             2             3             4  \
# 0   0.000000e+00  2.000000e+00  4.000000e+00  6.000000e+00  8.000000e+00
# 1   1.318731e+03  2.607778e+03  2.660372e+03  2.631314e+03  2.664529e+03
# 2  -1.439162e+03 -2.912298e+03 -2.872154e+03 -2.909147e+03 -2.868981e+03
# 3  -2.919942e+03 -5.891920e+03 -5.841740e+03 -5.857610e+03 -5.840287e+03
# 4  -1.600452e+03 -2.991468e+03 -2.998174e+03 -3.039368e+03 -2.955079e+03
# 5  -6.709301e+03 -1.341165e+04 -1.340776e+04 -1.340962e+04 -1.340103e+04
# 6   5.971693e+03  1.184110e+04  1.186165e+04  1.187126e+04  1.185302e+04
# 7   2.758026e+03  5.446852e+03  5.504274e+03  5.464845e+03  5.506352e+03
# 8  -1.915433e+03 -3.878899e+03 -3.843427e+03 -3.877871e+03 -3.847585e+03
# 9  -4.233644e+03 -8.736001e+03 -8.696259e+03 -8.733698e+03 -8.705334e+03
# 10 -2.391927e+03 -5.028204e+03 -5.068392e+03 -5.020962e+03 -5.072684e+03
# 11  1.303087e+04  2.260269e+04  2.264321e+04  2.260448e+04  2.263787e+04
# ...

# %%
df.to_csv('result.csv')
