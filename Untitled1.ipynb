# %% [markdown]
# <a href="https://colab.research.google.com/github/hanbuck30/Xcorps_gui/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("result_01.csv")
df
# Out:
#     Unnamed: 0             0             1             2             3  \
# 0            0  0.000000e+00  2.000000e+00  4.000000e+00  6.000000e+00
# 1            1  5.854682e+03  1.175673e+04  1.173478e+04  1.175011e+04
# 2            2  3.764526e+03  8.191356e+03  8.047410e+03  8.073919e+03
# 3            3  1.805373e+03  3.644787e+03  3.738039e+03  3.623128e+03
# 4            4  5.839371e+03  1.069817e+04  1.004322e+04  1.103479e+04
# 5            5  3.440090e+03  6.494009e+03  6.570027e+03  6.567591e+03
# 6            6  4.697130e+03  9.946660e+03  9.854370e+03  9.844915e+03
# 7            7  5.728573e+03  1.151312e+04  1.148906e+04  1.150554e+04
# 8            8 -1.524612e+03 -3.028416e+03 -2.964311e+03 -3.036105e+03
# 9            9  4.806184e+03  1.132757e+04  1.132795e+04  1.132666e+04
# 10          10  1.115218e+03  3.468611e+03  4.046046e+03  3.469460e+03
# 11          11  1.628034e+03  4.908555e+03  3.560789e+03  4.925699e+03
# ...

# %%
len(df.iloc[0])
# Out:
# 33488

# %%
for i in range(len(df.iloc[0])):
  if df.iloc[31][i] == 7 :
    print(i , "7")
  elif df.iloc[31][i] ==8:
    print(i , "8")
  elif df.iloc[31][i] ==11:
    print(i , "11")
  elif df.iloc[31][i] ==12:
    print(i , "12")
  elif df.iloc[31][i] ==15:
    print(i , "15")
  elif df.iloc[31][i] ==16:
    print(i , "16")
  elif df.iloc[31][i] ==19:
    print(i , "19")
  elif df.iloc[31][i] ==20:
    print(i , "20")
# Out:
# 2647 5
# 2947 6
# 3309 9
# 3668 10
# 3910 13
# 4270 14
# 4511 17
# 4931 18
# 5774 5
# 6133 6
# 6435 9
# 6795 10
# 7036 13
# 7396 14
# 7637 17
# 8057 18
# 8900 5
# 9320 6
# 9561 9
# 9921 10
# 10162 13
# 10522 14
# 10824 17
# 11184 18
# 12026 5
# 12446 6
# 12688 9
# 13047 10
# 13289 13
# 13649 14
# 13950 17
# 14310 18
# 15153 5
# 15572 6
# 15814 9
# 16174 10
# 16415 13
# 16835 14
# 17076 17
# 17436 18
# 18339 5
# 18699 6
# 18940 9
# 19300 10
# 19541 13
# 19961 14
# 20203 17
# 20562 18
# 21465 5
# 21825 6
# 22066 9
# 22426 10
# 22668 13
# 23088 14
# 23329 17
# 23689 18
# 24592 5
# 24951 6
# 25193 9
# 25553 10
# 25854 13
# 26214 14
# 26455 17
# 26815 18
# 27718 5
# 28078 6
# 28319 9
# 28679 10
# 28980 13
# 29340 14
# 29582 17
# 29941 18
# 30844 5
# 31204 6
# 31445 9
# 31866 10
# 32107 13
# 32467 14
# 32707 17
# 33067 18
